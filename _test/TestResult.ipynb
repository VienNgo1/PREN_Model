# %% [markdown]
# # Word accuracy
#
# |     **Word   accuracy**    	| **Regular** 	|         	|          	|          	| **Irregular** 	|          	|          	|
# |:--------------------------:	|:-----------:	|:-------:	|:--------:	|:--------:	|:-------------:	|:--------:	|:--------:	|
# |                            	|  **IIIT5k** 	| **SVT** 	| **IC03** 	| **IC13** 	|    **IC15**   	| **SVTP** 	| **CUTE** 	|
# | Test images                	|        3000 	|     648 	|     1107 	|     1015 	|          2077 	|      639 	|      289 	|
# | PREN, original publication 	|       92.1% 	|   92.0% 	|    94.9% 	|    94.7% 	|         79.2% 	|    83.9% 	|    81.3% 	|
# | PREN, pretrain retest      	|      91.47% 	| 90.726% 	|  91.147% 	|  92.808% 	|       76.071% 	|  81.550% 	|  76.042% 	|
# | delta                      	|      -0.63% 	|  -1.27% 	|   -3.75% 	|   -1.89% 	|        -3.13% 	|   -2.35% 	|   -5.26% 	|
#
# ---
